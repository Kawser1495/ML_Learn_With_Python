# %% [markdown]
# # Session 9: Pandas
#
# Welcome to the first hour of the session on Pandas Series. In this section, we will cover the basics of Pandas and an introduction to Pandas Series.

# %% [markdown]
# ## What is Pandas?
#
# Pandas is a powerful Python library used for data manipulation and analysis. It provides data structures like **Series** and **DataFrame** to handle labeled and relational data efficiently. Pandas is widely used in data science and machine learning workflows.
#
# **Key Features of Pandas:**
# - Fast and efficient data manipulation
# - Integrated handling of missing data
# - Alignment of data for operations
# - Data visualization support

# %%
# Install and import Pandas
import pandas as pd
print('Pandas version:', pd.__version__)
# Out:
# Pandas version: 2.3.3

# %% [markdown]
# ## Introduction to Pandas Series
#
# A **Pandas Series** is a one-dimensional labeled array capable of holding any data type. It is similar to a column in a spreadsheet but more powerful due to its labels (index).
#
# **Key Characteristics:**
# - Homogeneous data (all elements of the same type).
# - Labeled index (row labels).
# - Supports various data types (integers, floats, strings, etc.).
#
# **Creating a Series:**

# %%
# Creating a Pandas Series
import pandas as pd

# Creating a Series from a list
data = [10, 20, 30, 40, 50]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ### Attributes of a Series
#
# - **index**: Returns the index (row labels).
# - **values**: Returns the data values.
# - **dtype**: Returns the data type of elements in the Series.

# %%
# Exploring Series attributes
print('Index:', series.index)
print('Values:', series.values)
print('Data Type:', series.dtype)
# Out:
# Index: RangeIndex(start=0, stop=5, step=1)
# Values: [10 20 30 40 50]
# Data Type: int64

# %% [markdown]
# ### Creating a Series with Custom Indices
#
# You can assign custom labels to the indices when creating a Series. This makes data access easier and more intuitive.

# %%
# Creating a Series with custom indices
data = [100, 200, 300]
labels = ['a', 'b', 'c']
custom_series = pd.Series(data, index=labels)
print(custom_series)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ## Accessing Elements in a Series
#
# You can access elements in a Series using:
# - **Index labels**: Use the custom or default index.
# - **Integer indices**: Similar to lists in Python.
#
# **Examples:**

# %%
# Accessing elements
print('Element with index a:', custom_series['a'])
print('Element at position 1:', custom_series[1])
# Out:
# Element with index a: 100
# Element at position 1: 200
# C:\Users\ktl14\AppData\Local\Temp\ipykernel_21296\1212875187.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Element at position 1:', custom_series[1])

# %% [markdown]
# ## Basic Operations on Series
#
# Pandas Series supports various operations:
# - Element-wise operations (e.g., addition, multiplication).
# - Applying NumPy functions.
# - Filtering based on conditions.

# %%
import numpy as np
# Basic operations on Series
series = pd.Series([1, 2, 3, 4, 5])
print('Original Series:\n', series)

# Element-wise operations
print('\nSeries + 10:\n', series + 10)
print('\nSeries * 2:\n', series * 2)

# Applying a NumPy function
print('\nSquare root:\n', np.sqrt(series))
# Out:
# Original Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Series + 10:
#  0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64
#
# Series * 2:
#  0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
#
# Square root:
#  0    1.000000
# 1    1.414214
# 2    1.732051
# 3    2.000000
# 4    2.236068
# dtype: float64

# %% [markdown]
# ## Exercise
#
# 1. Create a Pandas Series from a dictionary where keys are student names and values are their scores.
# 2. Find the mean score.
# 3. Access the score of a specific student using their name as the index.
# 4. Multiply all scores by 1.1 to add a 10% bonus.

# %%
import pandas as pd

students = {
    'Amit': 85,
    'Rahim': 92,
    'Karim': 78,
    'Sonia': 88
}

series = pd.Series(students)
print("Series:\n", series)
# Out:
# Series:
#  Amit     85
# Rahim    92
# Karim    78
# Sonia    88
# dtype: int64

# %%
mean_score = series.mean()
print("Mean Score:", mean_score)
# Out:
# Mean Score: 85.75

# %%
print("Rahim's Score:", series['Rahim'])
# Out:
# Rahim's Score: 92

# %%
bonus_series = series * 1.1
print("Scores with Bonus:\n", bonus_series)
# Out:
# Scores with Bonus:
#  Amit      93.5
# Rahim    101.2
# Karim     85.8
# Sonia     96.8
# dtype: float64

# %% [markdown]
# ## Series Methods
#
# Pandas Series comes with a variety of built-in methods to make data manipulation easier. Here are some commonly used methods:
#
# - **`head()`**: Displays the first n rows.
# - **`tail()`**: Displays the last n rows.
# - **`describe()`**: Provides summary statistics.
# - **`value_counts()`**: Counts unique values.
# - **`sort_values()`**: Sorts the Series.
# - **`apply()`**: Applies a function to each element in the Series.
#
# Let's explore these methods with examples.

# %%
# Sample Series
data = [50, 20, 30, 40, 10]
labels = ['a', 'b', 'c', 'd', 'e']
series = pd.Series(data, index=labels)

# Using Series methods
print('First 3 elements:\n', series.head(3))
print('\nLast 2 elements:\n', series.tail(2))
print('\nSummary statistics:\n', series.describe())
# Out:
# First 3 elements:
#  a    50
# b    20
# c    30
# dtype: int64
#
# Last 2 elements:
#  d    40
# e    10
# dtype: int64
#
# Summary statistics:
#  count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
# Counting unique values and sorting
data = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
series = pd.Series(data)

print('Value counts:\n', series.value_counts())
print('\nSorted values:\n', series.sort_values())
# Out:
# Value counts:
#  apple     3
# banana    2
# orange    1
# Name: count, dtype: int64
#
# Sorted values:
#  0     apple
# 2     apple
# 5     apple
# 1    banana
# 4    banana
# 3    orange
# dtype: object

# %% [markdown]
# ### Applying Functions with `apply()`
#
# The `apply()` method allows you to apply custom or built-in functions to each element in the Series.

# %%
# Using apply() to apply a lambda function
series = pd.Series([1, 2, 3, 4, 5])
print('Original Series:\n', series)

# Squaring each element
squared = series.apply(lambda x: x ** 2)
print('\nSquared Series:\n', squared)
# Out:
# Original Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Squared Series:
#  0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %% [markdown]
# ## Series with Python Functionalities
#
# Pandas Series can be combined with native Python functionalities for tasks such as:
# - Iterating through elements.
# - Performing mathematical operations.
# - Using conditionals.
#
# Let's look at some examples:

# %%
# Iterating through a Series
series = pd.Series([10, 20, 30, 40])
for value in series:
    print('Value:', value)
# Out:
# Value: 10
# Value: 20
# Value: 30
# Value: 40

# %%
# Using conditionals
series = pd.Series([10, 20, 30, 40])

# Elements greater than 20
filtered = series[series > 20]
print('Filtered Series:\n', filtered)
# Out:
# Filtered Series:
#  2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## Boolean Indexing on Series
#
# Boolean indexing allows you to filter data based on conditions. It returns a subset of the Series where the condition is `True`.
#
# **Examples of Boolean Indexing:**

# %%
# Boolean indexing example
series = pd.Series([10, 15, 20, 25, 30])

# Condition: Values greater than 20
print('Values greater than 20:\n', series[series > 20])
# Out:
# Values greater than 20:
#  3    25
# 4    30
# dtype: int64

# %% [markdown]
# ### Compound Conditions
#
# You can combine multiple conditions using logical operators such as:
# - **`&`**: Logical AND
# - **`|`**: Logical OR
#
# For example:

# %%
# Compound condition example
series = pd.Series([10, 15, 20, 25, 30])

# Condition: Values greater than 10 and less than 30
filtered = series[(series > 10) & (series < 30)]
print('Filtered values:\n', filtered)
# Out:
# Filtered values:
#  1    15
# 2    20
# 3    25
# dtype: int64

# %% [markdown]
# ## Exercise
#
# 1. Create a Series of random integers between 1 and 50 (10 elements).
# 2. Use boolean indexing to find all elements greater than 25.
# 3. Apply a function to subtract 5 from each of these elements.
# 4. Sort the resulting Series in descending order.

# %%
import pandas as pd
import numpy as np

# 1. Create a Series of random integers between 1 and 50 (10 elements)
series = pd.Series(np.random.randint(1, 51, 10))
print("Original Series:\n", series)

# 2. Find all elements greater than 25
greater_than_25 = series[series > 25]
print("\nElements > 25:\n", greater_than_25)

# 3. Subtract 5 from each of these elements
subtracted = greater_than_25 - 5
print("\nAfter subtracting 5:\n", subtracted)

# 4. Sort the results in descending order
sorted_series = subtracted.sort_values(ascending=False)
print("\nSorted in descending order:\n", sorted_series)
# Out:
# Original Series:
#  0    33
# 1     7
# 2     2
# 3    38
# 4    30
# 5    10
# 6    40
# 7    28
# 8    50
# 9    16
# dtype: int32
#
# Elements > 25:
#  0    33
# 3    38
# 4    30
# 6    40
# 7    28
# 8    50
# dtype: int32
#
# After subtracting 5:
#  0    28
# 3    33
# 4    25
# 6    35
# 7    23
# 8    45
# dtype: int32
#
# Sorted in descending order:
#  8    45
# 6    35
# 3    33
# 0    28
# 4    25
# 7    23
# dtype: int32

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Load a dataset
import pandas as pd
df = pd.read_csv(r'E:\ML_Learn_With_Python\Day10\series.csv')
df
# Out:
#    Index    Name  Marks
# 0      0   Akash  10.00
# 1      1  Batash  20.00
# 2      2   pahar  30.00
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
df.head(6)
# Out:
#    Index    Name  Marks
# 0      0   Akash   10.0
# 1      1  Batash   20.0
# 2      2   pahar   30.0
# 3      3  Shobuj   10.0
# 4      4   Sagor   50.0
# 5      5    Nodi   70.0

# %%
df.tail()
# Out:
#    Index    Name  Marks
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
df.describe()
# Out:
#          Index      Marks
# count  8.00000   8.000000
# mean   3.50000  39.431250
# std    2.44949  25.174008
# min    0.00000  10.000000
# 25%    1.75000  17.500000
# 50%    3.50000  40.000000
# 75%    5.25000  59.087500
# max    7.00000  70.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   8 non-null      int64
#  1   Name    8 non-null      object
#  2   Marks   8 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 324.0+ bytes

# %% [markdown]
# ## Introduction to Data Visualization
#
# Data visualization is a crucial step in data analysis as it helps to:
# - Summarize large datasets visually.
# - Identify trends, patterns, and outliers.
# - Communicate insights effectively.
#
# We'll use two powerful libraries:
#
# - **Matplotlib**: A versatile library for creating static, animated, and interactive visualizations.
# - **Seaborn**: Built on top of Matplotlib, it provides a high-level interface for drawing attractive statistical graphics.

# %% [markdown]
# ## Plotting with Matplotlib
#
# Matplotlib provides a simple interface to create visualizations from Pandas Series. Here are some commonly used plot types:
#
# - **Line plot**: Useful for continuous data.
# - **Bar plot**: Ideal for categorical data.
# - **Histogram**: Displays the distribution of data.
#
# Let's explore these plots with examples.

# %%
df
# Out:
#    Index    Name  Marks
# 0      0   Akash  10.00
# 1      1  Batash  20.00
# 2      2   pahar  30.00
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Pandas and Matplotlib installed!")
# Out:
# Pandas and Matplotlib installed!

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Line plot
plt.figure(figsize=(16, 8))
df.plot(kind='line', title='Line Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (you must have some data to plot)
df = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Value': [10, 25, 35, 20, 40]
})

# Line plot
plt.figure(figsize=(16, 8))
df.plot(kind='line', x='Category', y='Value', title='Line Plot')

plt.xlabel('Category')
plt.ylabel('Value')

plt.show()

# %%
# Bar plot
plt.figure(figsize=(8, 4))
df.plot(kind='bar', color='skyblue', title='Bar Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 4))
df['Marks'].plot(kind='hist', bins=3, color='green', title='Histogram')
plt.xlabel('Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'Marks': [40, 55, 70, 65, 90]
})

plt.figure(figsize=(8, 4))
df['Marks'].plot(kind='hist', bins=3, color='green', title='Histogram')
plt.xlabel('Marks')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create sample data with a Marks column
df = pd.DataFrame({
    'Marks': [40, 55, 70, 65, 90]
})

# Histogram
plt.figure(figsize=(8, 4))
df['Marks'].plot(kind='hist', bins=3, color='green', title='Histogram')

plt.xlabel('Marks')
plt.show()

# %% [markdown]
# ### Enhancing Visualizations
#
# You can customize Matplotlib plots by adding features like:
# - Titles and labels
# - Grid lines
# - Annotations
#
# Example:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(32, 8))
df['Marks'].plot(kind='pie', title='Enhanced Line Plot', color='purple')
plt.xlabel('Category')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame (only if you don't already have one)
df = pd.DataFrame({
    'Marks': [40, 55, 70, 65, 90]
})

# Pie Chart
plt.figure(figsize=(8, 8))      # must be two values (width, height)
df['Marks'].plot(
    kind='pie',
    title='Marks Distribution',
    autopct='%1.1f%%'            # shows percentage
)

plt.ylabel('')                   # remove default ylabel for clean look
plt.show()

# %% [markdown]
# ## Plotting with Seaborn
#
# Seaborn makes it easy to create informative and attractive visualizations. Commonly used plots for Series include:
#
# - **Barplot**
# - **KDE Plot** (Kernel Density Estimate)
#
# Let's explore these plots.

# %%
import seaborn as sns

# Barplot using Seaborn
sns.barplot(x=df.Name, y=df.Marks, palette='coolwarm')
plt.title('Marks by Name')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_396\2305290057.py in ?()
#       1 import seaborn as sns
#       2
#       3 # Barplot using Seaborn
# ----> 4 sns.barplot(x=df.Name, y=df.Marks, palette='coolwarm')
#       5 plt.title('Marks by Name')
#       6 plt.xlabel('Name')
#       7 plt.ylabel('Marks')
#
# e:\ML_Learn_With_Python\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
# KDE Plot
sns.kdeplot(df, shade=True, color='orange')
plt.title('KDE Plot')
plt.xlabel('Value')
plt.show()
# Out:
# C:\Users\ktl14\AppData\Local\Temp\ipykernel_396\3207140973.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df, shade=True, color='orange')

# %% [markdown]
# ## Exercise
#
# 1. Create a Pandas Series with random data (10 elements).
# 2. Plot the following visualizations:
#    - Line Plot
#    - Bar Plot
#    - KDE Plot
# 3. Enhance at least one of the visualizations by adding labels, titles, and custom colors.
# 4. Save one of the plots as an image file using `plt.savefig()`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Create a Pandas Series with random data (10 elements)
series = pd.Series(np.random.randint(10, 100, 10))
print("Random Series:\n", series)

# 2a. Line Plot
plt.figure(figsize=(8, 4))
series.plot(kind='line', color='blue', marker='o',
            title='Line Plot of Random Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# 2b. Bar Plot
plt.figure(figsize=(8, 4))
series.plot(kind='bar', color='orange', title='Bar Plot of Random Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# 2c. KDE Plot (using Seaborn)
plt.figure(figsize=(8, 4))
sns.kdeplot(series, shade=True, color='green')
plt.title('KDE Plot of Random Data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# 4. Save one of the plots as an image file
plt.figure(figsize=(8, 4))
series.plot(kind='line', color='purple', marker='x', title='Saved Line Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.savefig('line_plot.png')  # Saves in current working directory
plt.show()
# Out:
# Random Series:
#  0    42
# 1    59
# 2    46
# 3    57
# 4    23
# 5    50
# 6    42
# 7    11
# 8    73
# 9    94
# dtype: int32
# C:\Users\ktl14\AppData\Local\Temp\ipykernel_396\3261167636.py:28: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(series, shade=True, color='green')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Random Series
s = pd.Series(np.random.randint(10, 100, 10))

# 2a. Line Plot
s.plot(kind='line', color='blue', title='Line Plot')
plt.show()

# 2b. Bar Plot
s.plot(kind='bar', color='orange', title='Bar Plot')
plt.show()

# 2c. KDE Plot
sns.kdeplot(s, shade=True, color='green')
plt.title('KDE Plot')
plt.show()

# 3 & 4. Enhanced Line Plot + Save
s.plot(kind='line', color='purple', marker='o', title='Saved Line Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.savefig('line_plot.png')
plt.show()
# Out:
# C:\Users\ktl14\AppData\Local\Temp\ipykernel_396\2124168202.py:18: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(s, shade=True, color='green')
